# %% [markdown]
# ### Explore Pandas
#
# Ww will study an 'easy' cluster, Alpha Persei
#
# This will be the basis for our laboratory exercise October 28 and 30

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
input_file = 'AlphaPer_3350.txt'

#make a data frame
AP = pd.read_csv(input_file)
# Out:
# /tmp/ipykernel_111/3830089109.py:4: DtypeWarning: Columns (14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   AP = pd.read_csv(input_file)
